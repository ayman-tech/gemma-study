# %%
from huggingface_hub import login
login("YOUR_HF_TOKEN_HERE")

# %%
# !git clone https://github.com/ayman-tech/gemma-study.git
# !mv gemma-study/* .
# !mv gemma-study/.git .
# !git checkout ziyadh -f
# Out:
# fatal: destination path 'gemma-study' already exists and is not an empty directory.
# mv: cannot stat 'gemma-study/*': No such file or directory
# mv: cannot stat 'gemma-study/.git': No such file or directory
# Already on 'ziyadh'
# Your branch is up to date with 'origin/ziyadh'.

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 1.19 KiB | 1.19 MiB/s, done.
# From https://github.com/ayman-tech/gemma-study
#    4e61d1f..eaf522d  ziyadh     -> origin/ziyadh
# Updating 4e61d1f..eaf522d
# Fast-forward
#  train_colab.py | 38 +++++++++++++++++++++-----------------
#  1 file changed, 21 insertions(+), 17 deletions(-)

# %%
# Cell 1 - Reset everything to Colab defaults
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu128
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu128
# ...

# %%
# !pip install \
    transformers \
    peft \
    trl \
    accelerate \
    bitsandbytes \
    datasets \
    sentencepiece psutil
# Out:
# ...
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 447, in run
#     conflicts = self._determine_conflicts(to_install)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 578, in _determine_conflicts
#     return check_install_conflicts(to_install)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !pip install --upgrade --force-reinstall transformers
# Out:
# ...
#   Using cached transformers-5.7.0-py3-none-any.whl.metadata (33 kB)
# ...
#   Using cached huggingface_hub-1.13.0-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# ...
#   Using cached packaging-26.2-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# ...
#   Using cached regex-2026.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# ...
#   Using cached tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# ...
#   Using cached typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# ...
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# ...

# %%
import transformers
print(f"Transformers version: {transformers.__version__}")  # needs 4.50+

from transformers import AutoTokenizer
tok = AutoTokenizer.from_pretrained("google/gemma-3-270m-it")
print("Gemma 3 tokenizer loaded ✓")
# Out:
# Transformers version: 5.7.0
# Gemma 3 tokenizer loaded ✓

# %%
# Cell 1 - Fix bitsandbytes and triton
# !pip install --upgrade bitsandbytes triton
# !pip install --upgrade transformers peft trl accelerate datasets sentencepiece psutil
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 8.0 MB/s eta 0:00:00
# ...
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 5.2 MB/s eta 0:00:00
# Using cached fsspec-2026.2.0-py3-none-any.whl (202 kB)
# ...
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2026.4.0
#     Uninstalling fsspec-2026.4.0:
#       Successfully uninstalled fsspec-2026.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2026.2.0 which is incompatible.
# pyiceberg 0.11.1 requires rich<15.0.0,>=10.11.0, but you have rich 15.0.0 which is incompatible.
# ...

# %%
# Check bitsandbytes CPU BF16 support
import bitsandbytes as bnb
import torch

# Test BF16 on CPU via bitsandbytes
x = torch.randn(10, 10).to(torch.bfloat16)
print(f"BF16 tensor created: {x.dtype}")
print(f"bitsandbytes version: {bnb.__version__}")
# Out:
# BF16 tensor created: torch.bfloat16
# bitsandbytes version: 0.49.2

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
tokenizer = AutoTokenizer.from_pretrained("google/gemma-3-270m-it")
print("Tokenizer ✓")
model = AutoModelForCausalLM.from_pretrained("google/gemma-3-270m-it")
print("Model ✓")
# Out:
# Tokenizer ✓
# model.safetensors:   0%|          | 0.00/536M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/236 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# Model ✓

# %%
# !pip install --upgrade torchao
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 34.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
# ...

# %%
# !python train_colab.py --quant bf16 --device cpu --epochs 1
# Out:
# Skipping import of cpp extensions due to incompatible torch version. Please upgrade to torch >= 2.11.0 (found 2.10.0+cpu).
#
# ...
#   Gemma 3 270M | quant=BF16 | device=CPU
# ...
#   Device : CPU
#   True BF16 supported on this CPU!
#   Quant  : BF16
#   Dtype  : torch.bfloat16
#   Rows   : 100
#   Epochs : 1
#   Batch  : 1 (effective: 8)
# ...
#
# [1/4] Loading tokenizer ...
#       Tokenizer loaded
# [2/4] Preparing LoRA config ...
#       LoRA config ready
#       Loading model ...
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights: 100% 236/236 [00:00<00:00, 2397.49it/s]
#       Model loaded with torch.bfloat16
# [3/4] Loading dataset (100 rows) ...
#       Dataset ready: 100 rows
# [4/4] Starting training ...
#
# trainable params: 1,898,496 || all params: 269,996,672 || trainable%: 0.7032
# ...
